# %%
import pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uri = "mongodb+srv://vishnu08:qwerty12@cluster0.itbkwy6.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(uri, server_api=ServerApi('1'))

# %%
print(client.list_database_names())
# Out:
# ['blog', 'my_database', 'mydatabase', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %%
mydb = client['my_database']
print(mydb.list_collection_names())
# Out:
# ['my_collection1']

# %%
database=client.my_database

# %%
mycollection=database.my_collection1

# %%
cursor=mycollection.find()

# %%
list1= list(cursor)

# %%
df= pd.DataFrame(list1)
df
# Out:
#                          _id      name  age          city
# 0   6566e3bcc7e1be420e0591fc     Alice   30       Seattle
# 1   6566e4c3c7e1be420e0591fd       Bob   25   Los Angeles
# 2   6566e542c7e1be420e0591fe       Bob   25   Los Angeles
# 3   6566e546c7e1be420e0591ff   Charlie   22       Chicago
# 4   6566e546c7e1be420e059200     David   33       Houston
# 5   6566e546c7e1be420e059201     Emily   28  Philadelphia
# 6   6566e546c7e1be420e059202     Frank   35       Phoenix
# 7   6566e546c7e1be420e059203     Grace   27   San Antonio
# 8   6566e546c7e1be420e059204     Harry   32     San Diego
# 9   6566e546c7e1be420e059205  Isabella   29        Dallas
# 10  6566e546c7e1be420e059206      Jack   34      San Jose
# 11  6566e546c7e1be420e059207  Kimberly   26  Jacksonville
# 12  6566e546c7e1be420e059208      Liam   31  Indianapolis
# 13  6566e546c7e1be420e059209    Olivia   24      Columbus
# 14  6566e546c7e1be420e05920a     Peter   36        Austin

# %%
df.drop(columns=['_id'], inplace=True)

# %%
df
# Out:
#         name  age          city
# 0      Alice   30       Seattle
# 1        Bob   25   Los Angeles
# 2        Bob   25   Los Angeles
# 3    Charlie   22       Chicago
# 4      David   33       Houston
# 5      Emily   28  Philadelphia
# 6      Frank   35       Phoenix
# 7      Grace   27   San Antonio
# 8      Harry   32     San Diego
# 9   Isabella   29        Dallas
# 10      Jack   34      San Jose
# 11  Kimberly   26  Jacksonville
# 12      Liam   31  Indianapolis
# 13    Olivia   24      Columbus
# 14     Peter   36        Austin

# %%
df.describe()
# Out:
#              age
# count  15.000000
# mean   29.133333
# std     4.307247
# min    22.000000
# 25%    25.500000
# 50%    29.000000
# 75%    32.500000
# max    36.000000

# %%
sns.set(rc={'figure.figsize':(15,5)})
a = sns.barplot(x='name',y='age',data=df)

# %%
mydb1 = client['sample_training']
print(mydb1.list_collection_names())
# Out:
# ['routes', 'zips', 'posts', 'trips', 'companies', 'grades', 'inspections']

# %%
database1=client.sample_training

# %%
mycollection1=database1.companies

# %%
cursor1=mycollection1.find()

# %%
list2= list(cursor1)

# %%
df1= pd.DataFrame(list2)
df1
# Out:
#                            _id                 name            permalink  \
# 0     52cdef7c4bab8bd675297d8a             Wetpaint                 abc2
# 1     52cdef7c4bab8bd675297d8e             Facebook             facebook
# 2     52cdef7c4bab8bd675297d8f            Omnidrive            omnidrive
# 3     52cdef7c4bab8bd675297d94              Twitter              twitter
# 4     52cdef7c4bab8bd675297d95          StumbleUpon          stumbleupon
# ...                        ...                  ...                  ...
# 9495  52cdef7f4bab8bd67529c6f0              Intergy              intergy
# 9496  52cdef7f4bab8bd67529c6f4             Geekdive             geekdive
# 9497  52cdef7f4bab8bd67529c6f7           AfterLogic           afterlogic
# 9498  52cdef7f4bab8bd67529c6f8          goBookmaker          gobookmaker
# 9499  52cdef7f4bab8bd67529c6f9  EnteGreat Solutions  entegreat-solutions
#
#                                          crunchbase_url  \
# ...

# %%
df1.count()
# Out:
# _id                    9500
# name                   9500
# permalink              9500
# crunchbase_url         9500
# homepage_url           8523
# blog_url               8520
# blog_feed_url          8459
# twitter_username       5714
# category_code          8093
# number_of_employees    4448
# founded_year           6651
# founded_month          3992
# founded_day            2782
# deadpooled_year         480
# tag_list               7440
# alias_list             4477
# email_address          8476
# phone_number           8467
# description            6206
# created_at             9500
# updated_at             9500
# overview               8495
# image                  8143
# products               9500
# relationships          9500
# competitions           9500
# providerships          9500
# total_money_raised     9500
# funding_rounds         9500
# investments            9500
# acquisition            1326
# acquisitions           9500
# offices                9500
# ...

# %%
df2 = df1.drop(['_id', 'permalink', 'crunchbase_url','homepage_url','blog_url','blog_feed_url','twitter_username'], axis=1)

# %%
df2
# Out:
#                      name    category_code  number_of_employees  founded_year  \
# 0                Wetpaint              web                 47.0        2005.0
# 1                Facebook           social               5299.0        2004.0
# 2               Omnidrive  network_hosting                  NaN        2005.0
# 3                 Twitter           social               1300.0        2006.0
# 4             StumbleUpon              web                  NaN        2002.0
# ...                   ...              ...                  ...           ...
# 9495              Intergy         software                  NaN        2003.0
# 9496             Geekdive             None                  NaN           NaN
# 9497           AfterLogic         software                  NaN        2002.0
# 9498          goBookmaker              web                  NaN           NaN
# 9499  EnteGreat Solutions         software                  NaN           NaN
#
# ...

# %%
df2.drop(['email_address','tag_list','alias_list','offices','milestones','video_embeds','screenshots','external_links'], axis=1,inplace=True)

# %%
df2
# Out:
#                      name    category_code  number_of_employees  founded_year  \
# 0                Wetpaint              web                 47.0        2005.0
# 1                Facebook           social               5299.0        2004.0
# 2               Omnidrive  network_hosting                  NaN        2005.0
# 3                 Twitter           social               1300.0        2006.0
# 4             StumbleUpon              web                  NaN        2002.0
# ...                   ...              ...                  ...           ...
# 9495              Intergy         software                  NaN        2003.0
# 9496             Geekdive             None                  NaN           NaN
# 9497           AfterLogic         software                  NaN        2002.0
# 9498          goBookmaker              web                  NaN           NaN
# 9499  EnteGreat Solutions         software                  NaN           NaN
#
# ...

# %%
df2.drop(['funding_rounds','acquisition','acquisitions','partners','ipo','created_at','phone_number','providerships'], axis=1,inplace=True)

# %%
df2
# Out:
#                      name    category_code  number_of_employees  founded_year  \
# 0                Wetpaint              web                 47.0        2005.0
# 1                Facebook           social               5299.0        2004.0
# 2               Omnidrive  network_hosting                  NaN        2005.0
# 3                 Twitter           social               1300.0        2006.0
# 4             StumbleUpon              web                  NaN        2002.0
# ...                   ...              ...                  ...           ...
# 9495              Intergy         software                  NaN        2003.0
# 9496             Geekdive             None                  NaN           NaN
# 9497           AfterLogic         software                  NaN        2002.0
# 9498          goBookmaker              web                  NaN           NaN
# 9499  EnteGreat Solutions         software                  NaN           NaN
#
# ...

# %%
df2.drop(['overview','image','products','relationships','competitions','updated_at','deadpooled_url'], axis=1,inplace=True)

# %%
df2
# Out:
#                      name    category_code  number_of_employees  founded_year  \
# 0                Wetpaint              web                 47.0        2005.0
# 1                Facebook           social               5299.0        2004.0
# 2               Omnidrive  network_hosting                  NaN        2005.0
# 3                 Twitter           social               1300.0        2006.0
# 4             StumbleUpon              web                  NaN        2002.0
# ...                   ...              ...                  ...           ...
# 9495              Intergy         software                  NaN        2003.0
# 9496             Geekdive             None                  NaN           NaN
# 9497           AfterLogic         software                  NaN        2002.0
# 9498          goBookmaker              web                  NaN           NaN
# 9499  EnteGreat Solutions         software                  NaN           NaN
#
# ...

# %%
df2.shape
# Out:
# (9500, 12)

# %%
df3=df2.copy()

# %%
df3.dropna(subset=['number_of_employees','founded_year','founded_month','founded_day','deadpooled_year','total_money_raised','deadpooled_month','deadpooled_day'],inplace=True)

# %%
df3
# Out:
#                      name category_code  number_of_employees  founded_year  \
# 48                  Fleck           web                  3.0        2006.0
# 49                Coghead           web                 21.0        2003.0
# 60                TripHub           web                  6.0        2005.0
# 86                  Ujogo           web                  6.0        2007.0
# 234           CrowdSpirit           web                  3.0        2007.0
# ...                   ...           ...                  ...           ...
# 7777             Tempolib        mobile                  4.0        2009.0
# 8033             FanFeedr           web                  5.0        2008.0
# 8115               ZodBod           web                  1.0        2009.0
# 8224                Libox           web                  6.0        2008.0
# 8679  Sprowtt Marketplace         legal                  6.0        2008.0
#
#       founded_month  founded_day  deadpooled_year  \
# ...

# %%
df3.drop(['description','investments'],axis=1,inplace=True)

# %%
df3
# Out:
#                      name category_code  number_of_employees  founded_year  \
# 48                  Fleck           web                  3.0        2006.0
# 49                Coghead           web                 21.0        2003.0
# 60                TripHub           web                  6.0        2005.0
# 86                  Ujogo           web                  6.0        2007.0
# 234           CrowdSpirit           web                  3.0        2007.0
# ...                   ...           ...                  ...           ...
# 7777             Tempolib        mobile                  4.0        2009.0
# 8033             FanFeedr           web                  5.0        2008.0
# 8115               ZodBod           web                  1.0        2009.0
# 8224                Libox           web                  6.0        2008.0
# 8679  Sprowtt Marketplace         legal                  6.0        2008.0
#
# ...

# %%
gp1=df3.groupby('category_code')['name'].value_counts()
gp1
# Out:
# category_code  name
# advertising    Unity 4 Humanity       2
#                Advaliant              1
#                Povo                   1
# consulting     Engineering Ideas      1
# ecommerce      Storrz                 1
#                                      ..
# web            RODECO ICT Services    1
#                PLUQ                   1
#                Orgoo                  1
#                MyFrontSteps           1
#                mymission2             1
# Name: count, Length: 102, dtype: int64

# %%
gp2=df3.groupby('category_code')['founded_year'].value_counts()
gp2
# Out:
# category_code     founded_year
# advertising       2006             2
#                   2013             1
#                   2007             1
# consulting        2008             1
# ecommerce         2008             2
#                   2007             1
# enterprise        2008             1
#                   2009             1
# games_video       2007             5
#                   2009             1
#                   2004             1
#                   2006             1
#                   2008             1
# legal             2008             1
#                   2009             1
# mobile            2007             3
#                   2008             2
#                   2012             1
#                   2009             1
#                   2006             1
# network_hosting   2007             2
#                   2008             1
# other             2008             2
# public_relations  2007             3
# ...

# %%
gp3=df3.groupby('category_code')['total_money_raised'].value_counts()
gp3
# Out:
# category_code  total_money_raised
# advertising    $250k                 2
#                $0                    1
#                $100k                 1
# consulting     $60k                  1
# ecommerce      $0                    1
#                                     ..
# web            $450k                 1
#                $3M                   1
#                $325k                 1
#                $300k                 1
#                €750k                 1
# Name: count, Length: 73, dtype: int64

# %%
gp4=df3.groupby('category_code')['total_money_raised'].max()
gp4
# Out:
# category_code
# advertising         $250k
# consulting           $60k
# ecommerce             $9M
# enterprise          $500k
# games_video           $5M
# legal                  $0
# mobile              €200k
# network_hosting       £2M
# other                $10k
# public_relations    €550k
# search              $1.5M
# software             £50k
# web                 €750k
# Name: total_money_raised, dtype: object

# %%
gp4=df3.groupby('category_code')['total_money_raised'].min()
gp4
# Out:
# category_code
# advertising            $0
# consulting           $60k
# ecommerce              $0
# enterprise             $0
# games_video         $1.3M
# legal                  $0
# mobile                 $0
# network_hosting        $0
# other                  $0
# public_relations       $0
# search                 $0
# software               $0
# web                    $0
# Name: total_money_raised, dtype: object

# %%
df3.head(50)
# Out:
#                                name     category_code  number_of_employees  \
# 48                            Fleck               web                    3
# 49                          Coghead               web                   21
# 60                          TripHub               web                    6
# 86                            Ujogo               web                    6
# 234                     CrowdSpirit               web                    3
# 251                          Trutap          software                   28
# 260                           Orgoo               web                   15
# 273                       RatePoint          software                   45
# 296                            mEgo               web                   15
# 305                        BuzzDash               web                    0
# 380                        Upcoming               web                    3
# ...

# %%
df3.tail(53)
# Out:
#                       name     category_code  number_of_employees  \
# 3253           Carticipate            mobile                    3
# 3314      My Best Interest          software                   10
# 3531               GoYoDeo       games_video                    6
# 3593               Statzen               web                    2
# 3621      Unity 4 Humanity       advertising                   15
# 3638                Storrz         ecommerce                    6
# 3834              Klatcher               web                    5
# 3979                Status               web                    2
# 4134               Linkbee               web                    3
# 4148    Club Scene Network       games_video                   36
# 4257                  Povo       advertising                    6
# 4473     Engineering Ideas        consulting                    3
# 4540  For Your Imagination       games_video                   10
# ...

# %%
gp5=df3.groupby('category_code')['number_of_employees'].sum()
gp5
# Out:
# category_code
# advertising          96
# consulting            3
# ecommerce            16
# enterprise           18
# games_video          77
# legal                 9
# mobile               91
# network_hosting      15
# other                14
# public_relations     52
# search               26
# software            464
# web                 338
# Name: number_of_employees, dtype: int32

# %%
df3['total_money_raised'].info
# Out:
# <bound method Series.info of 48       €225k
# 49      $11.2M
# 60          $0
# 86          $0
# 234         $0
#          ...
# 7777     €200k
# 8033        $0
# 8115      £25k
# 8224       $2M
# 8679        $0
# Name: total_money_raised, Length: 103, dtype: object>

# %%
df3['founded_year']=df3['founded_year'].astype(int)

# %%
df3['number_of_employees']=df3['number_of_employees'].astype(int,i)

# %%
df3
# Out:
#                      name category_code  number_of_employees  founded_year  \
# 48                  Fleck           web                    3          2006
# 49                Coghead           web                   21          2003
# 60                TripHub           web                    6          2005
# 86                  Ujogo           web                    6          2007
# 234           CrowdSpirit           web                    3          2007
# ...                   ...           ...                  ...           ...
# 7777             Tempolib        mobile                    4          2009
# 8033             FanFeedr           web                    5          2008
# 8115               ZodBod           web                    1          2009
# 8224                Libox           web                    6          2008
# 8679  Sprowtt Marketplace         legal                    6          2008
#
# ...

# %%
sns.set(rc={'figure.figsize':(19,10)})
ax= sns.countplot(data=df3,x='category_code')
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# ***we can observe from the graph above that the highest number companies are web based companies followed by software and mobile companies***

# %%
g1=df3.groupby(['category_code'],as_index=False)['number_of_employees'].sum().sort_values(by='number_of_employees',ascending=False)
sns.set(rc={'figure.figsize':(18,10)})
ax= sns.barplot(data=g1,x='category_code',y='number_of_employees')

# %% [markdown]
# ***from the graph above we can observe that software companies consists the highest number of employees***

# %%
ax= sns.countplot(x='founded_year',data=df3)
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# ***from the above graph we can see that most companies were founded on 2007 & 2008***

# %%
plt.figure(figsize=(19, 6))
plt.scatter(df3['category_code'], df3['founded_year'])
plt.xlabel('Category Code')
plt.ylabel('Founded Year')
plt.title('Scatter Plot of Founded Year by Category Code')
plt.show()

# %% [markdown]
# ***from the above graph we can see that most companies founded in the year 2000-2010 are web-based amd software-based***

# %% [markdown]
# # conclusion

# %% [markdown]
# **we can see that the highest employment and expansion involve web-based and software-based companies which inidcate their steady growth**
